# %% [markdown]
# ## Задача 1

# %% [markdown]
# ### 1.1

# %%
import pandas as pd
df= pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### 1.2

# %%
df['delta_renovated']=df['yr_renovated']-df['yr_built']
df['delta_renovated']=df['delta_renovated'].apply(lambda x: 0 if x<=0 else x)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ### 1.3

# %%
df['yr_selling']=0
df['mounth_selling']=0
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
# ...

# %% [markdown]
# ### 1.3

# %%
df.drop(columns=['date','zipcode','lat','long'], inplace=True)
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %% [markdown]
# ## Задача 2

# %%
clients = pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
5083000375, 7920100025, 1951600150, 809001400, 339600110,
1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
8861700030, 3303980210, 7731100066, 8146100580, 825069097,
3889100029, 9524100196]
})
clients
# Out:
#     client_id    house_id
# 0        1459  8965450190
# 1        4684  6823100225
# 2        3498  5104540330
# 3        3942  2131701075
# 4        4535  1522700060
# 5        2308  1189000207
# 6        2866  6821600300
# 7        2765  7137950720
# 8        1472  9510920050
# 9        4236  6131600255
# 10       2295  5428000070
# 11        939  1788800910
# 12       3840  8100400160
# 13        280  3123049142
# 14         20  6306800010
# 15       4332  5083000375
# 16       3475  7920100025
# 17       4213  1951600150
# 18       3113   809001400
# 19       4809   339600110
# 20       2134  1622049154
# 21       2242  1099600250
# 22       2068  8563000110
# 23       4929  2768100205
# 24       1384  3995700435
# 25       1589  8861700030
# 26       3317  3303980210
# 27       2260  7731100066
# 28       1727  8146100580
# 29       1764   825069097
# 30       1611  3889100029
# 31       1474  9524100196

# %% [markdown]
# ### 2.1

# %%
joined=clients.join(df)
joined
# Out:
#     client_id    house_id          id      price  bedrooms  bathrooms  \
# 0        1459  8965450190  7129300520   221900.0         3       1.00
# 1        4684  6823100225  6414100192   538000.0         3       2.25
# 2        3498  5104540330  5631500400   180000.0         2       1.00
# 3        3942  2131701075  2487200875   604000.0         4       3.00
# 4        4535  1522700060  1954400510   510000.0         3       2.00
# 5        2308  1189000207  7237550310  1225000.0         4       4.50
# 6        2866  6821600300  1321400060   257500.0         3       2.25
# 7        2765  7137950720  2008000270   291850.0         3       1.50
# 8        1472  9510920050  2414600126   229500.0         3       1.00
# 9        4236  6131600255  3793500160   323000.0         3       2.50
# 10       2295  5428000070  1736800520   662500.0         3       2.50
# 11        939  1788800910  9212900260   468000.0         2       1.00
# ...

# %% [markdown]
# ### 2.2

# %%
df['house_id'] = df.index
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
merged = clients.merge(df, on='house_id')
merged
# Out:
#     client_id  house_id          id      price  bedrooms  bathrooms  \
# 0        1459         0  7129300520   221900.0         3       1.00
# 1        4684         1  6414100192   538000.0         3       2.25
# 2        3498         2  5631500400   180000.0         2       1.00
# 3        3942         3  2487200875   604000.0         4       3.00
# 4        4535         4  1954400510   510000.0         3       2.00
# 5        2308         5  7237550310  1225000.0         4       4.50
# 6        2866         6  1321400060   257500.0         3       2.25
# 7        2765         7  2008000270   291850.0         3       1.50
# 8        1472         8  2414600126   229500.0         3       1.00
# 9        4236         9  3793500160   323000.0         3       2.50
# 10       2295        10  1736800520   662500.0         3       2.50
# 11        939        11  9212900260   468000.0         2       1.00
# 12       3840        12   114101516   310000.0         3       1.00
# ...

# %% [markdown]
# ## Задача 3

# %% [markdown]
# ### 3.1

# %%
df.groupby('bedrooms').agg({'price':'mean'}).sort_values('price', ascending=True)
# Out:
#                  price
# bedrooms
# 1         3.176429e+05
# 2         4.013727e+05
# 0         4.095038e+05
# 3         4.662321e+05
# 11        5.200000e+05
# 4         6.354195e+05
# 33        6.400000e+05
# 5         7.865998e+05
# 10        8.193333e+05
# 6         8.255206e+05
# 9         8.939998e+05
# 7         9.511847e+05
# 8         1.105077e+06

# %% [markdown]
# ### 3.2

# %%
df.groupby('condition').agg({'price': ['min', 'mean', 'max']})
# Out:
#               price
#                 min           mean        max
# condition
# 1           78000.0  334431.666667  1500000.0
# 2           80000.0  327287.145349  2555000.0
# 3           75000.0  542012.578148  7062500.0
# 4           89000.0  521200.390033  7700000.0
# 5          110000.0  612418.089359  3650000.0

# %% [markdown]
# ### 3.3

# %%
df.pivot_table(index='waterfront', columns='view', values='price', aggfunc='count', fill_value=0)
# Out:
# view            0    1    2    3    4
# waterfront
# 0           19489  331  955  491  184
# 1               0    1    8   19  135

# %% [markdown]
# ### 3.4

# %%
floor_bed=pd.crosstab(index=df['bedrooms'], columns=df['floors'])
floor_bed
# Out:
# floors     1.0  1.5   2.0  2.5  3.0  3.5
# bedrooms
# 0            4    0     6    0    2    1
# 1          162   21    12    1    3    0
# 2         1951  182   497    5  123    2
# 3         5455  786  3118   56  405    4
# 4         2383  698  3682   58   61    0
# 5          605  185   775   23   13    0
# 6          104   30   119   14    5    0
# 7            9    7    19    2    1    0
# 8            5    1     6    0    0    1
# 9            0    0     4    2    0    0
# 10           1    0     2    0    0    0
# 11           0    0     1    0    0    0
# 33           1    0     0    0    0    0

# %%
floor_bed.max().max()
# Out:
# 5455

# %% [markdown]
# ### 3.5

# %%
df.groupby(['grade', 'condition']).agg({'price': 'median'}).fillna(0)
## Некрасиво, доп.решение ниже
# Out:
#                      price
# grade condition
# 1     1           142000.0
# 3     2           280000.0
#       3            75000.0
#       5           262000.0
# 4     1           150000.0
#       2           145000.0
#       3           205000.0
#       4           238525.0
# 5     1           190000.0
#       2           180000.0
#       3           234475.0
#       4           229975.0
#       5           227450.0
# 6     1           255000.0
#       2           235000.0
#       3           265000.0
#       4           295000.0
#       5           285475.0
# 7     1           403500.0
#       2           305000.0
#       3           357500.0
#       4           390000.0
#       5           456000.0
# 8     1           932500.0
#       2           429000.0
#       3           485000.0
#       4           571250.0
#       5           696000.0
# 9     2           715000.0
#       3           689000.0
#       4           823500.0
#       5          1078000.0
# ...

# %%
df.pivot_table(index='grade', columns='condition', values='price', aggfunc='median', fill_value=0)
##Считаю, что такая таблица смотрится лучше
# Out:
# condition       1        2        3        4        5
# grade
# 1          142000        0        0        0        0
# 3               0   280000    75000        0   262000
# 4          150000   145000   205000   238525        0
# 5          190000   180000   234475   229975   227450
# 6          255000   235000   265000   295000   285475
# 7          403500   305000   357500   390000   456000
# 8          932500   429000   485000   571250   696000
# 9               0   715000   689000   823500  1078000
# 10              0  1752500   890000  1030000  1650000
# 11              0        0  1209500  1685000  2050000
# 12              0        0  1807500  2125000  1990000
# 13              0        0  2888000  5750000        0
